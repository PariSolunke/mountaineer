# %%
scomplex
# Out:
# {'nodes': defaultdict(list,
#              {'cube4_cluster0': [108, 122],
#               'cube4_cluster1': [78],
#               'cube5_cluster0': [122],
#               'cube5_cluster1': [108],
#               'cube6_cluster0': [122],
#               'cube6_cluster1': [108],
#               'cube7_cluster0': [212],
#               'cube7_cluster1': [108, 122],
#               'cube12_cluster0': [152],
#               'cube12_cluster1': [3],
#               'cube13_cluster0': [152],
#               'cube13_cluster1': [3],
#               'cube16_cluster0': [78],
#               'cube16_cluster1': [12],
#               'cube17_cluster0': [78],
#               'cube17_cluster1': [12],
#               'cube18_cluster0': [108, 122],
#               'cube18_cluster1': [78],
#               'cube19_cluster0': [122],
#               'cube19_cluster1': [108],
#               'cube20_cluster0': [122],
#               'cube20_cluster1': [108],
#               'cube21_cluster0': [212],
# ...
